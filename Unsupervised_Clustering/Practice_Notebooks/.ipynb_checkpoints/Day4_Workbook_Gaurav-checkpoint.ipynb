# %%
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = iris.drop('Id', axis = 1)
x= iris.SepalLengthCm
y= iris.SepalWidthCm

# %%
#Standard Scaling

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
x = iris.drop("Species", axis = 1)
y = iris.Species

# %%
#Standardizing the scale
x = sc.fit_transform(x)

# %%
#Apply PCA

from sklearn.decomposition import PCA
pc =PCA(n_components= 2)
Pcomp = pc.fit_transform(x)

# %%
pc.components_
# Out:
# array([[ 0.52237162, -0.26335492,  0.58125401,  0.56561105],
#        [ 0.37231836,  0.92555649,  0.02109478,  0.06541577]])

# %%
pc.explained_variance_ratio_
# Out:
# array([0.72770452, 0.23030523])

# %%
#PLot this

Principaldf = pd.DataFrame(Pcomp, columns = ['PrinComp1', 'PrinComp2'])
finaldf = pd.concat([Principaldf,y], axis=1)

# %%
finaldf.head()
# Out:
#    PrinComp1  PrinComp2      Species
# 0  -2.264542   0.505704  Iris-setosa
# 1  -2.086426  -0.655405  Iris-setosa
# 2  -2.367950  -0.318477  Iris-setosa
# 3  -2.304197  -0.575368  Iris-setosa
# 4  -2.388777   0.674767  Iris-setosa

# %%
finaldf.shape
# Out:
# (150, 3)

# %%
#PLot this
plt.figure()
plt.scatter(finaldf.PrinComp1,finaldf.PrinComp2)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.model_selection import train_test_split
x= finaldf.drop('Species', axis=1)
y= finaldf.Species
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state = 122)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
ypred = logreg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, ypred)
# Out:
# 0.9333333333333333

# %%
import seaborn as sns

# %%
plt.figure()
plt.scatter(finaldf.PrinComp1, finaldf.PrinComp2, c= ['r','g','b'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="704">

# %%
plt.figure()
sns.scatterplot(x='PrinComp1', y='PrinComp2',hue='Species',data= finaldf)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="704">

# %%
plt.figure()
sns.scatterplot(iris["SepalLengthCm"], iris["SepalWidthCm"], hue = "Species", data = iris)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="704">

# %% [markdown]
# # Boston House Price

# %%
house = pd.read_csv('train.csv')

# %%
house.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL           65     8450   Pave  Grvl      Reg
# 1   2          20       RL           80     9600   Pave  Grvl      Reg
# 2   3          60       RL           68    11250   Pave  Grvl      IR1
# 3   4          70       RL           60     9550   Pave  Grvl      IR1
# 4   5          60       RL           84    14260   Pave  Grvl      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0     Gd  MnPrv        Shed       0
# 1         Lvl    AllPub    ...            0     Gd  MnPrv        Shed       0
# 2         Lvl    AllPub    ...            0     Gd  MnPrv        Shed       0
# 3         Lvl    AllPub    ...            0     Gd  MnPrv        Shed       0
# 4         Lvl    AllPub    ...            0     Gd  MnPrv        Shed       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house.shape
# Out:
# (1460, 81)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1460 non-null int64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            1460 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
import seaborn as sns

plt.figure()
sns.heatmap(house.isnull())
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
house=pd.get_dummies(house)

# %%
house.drop('Id', axis=1, inplace=True)

# %%
col = house.columns

# %%
house=sc.fit_transform(house)
# Out:
# C:\Users\Gaurav\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Gaurav\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
house = pd.DataFrame(house, columns=col)

# %%
house.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    0.073375    -0.220875 -0.207142     0.651479    -0.517200   1.050994
# 1   -0.872563     0.460320 -0.091886    -0.071836     2.179628   0.156734
# 2    0.073375    -0.084636  0.073480     0.651479    -0.517200   0.984752
# 3    0.309859    -0.447940 -0.096897     0.651479    -0.517200  -1.863632
# 4    0.073375     0.641972  0.375148     1.374795    -0.517200   0.951632
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0      0.878668    0.514104    0.575425   -0.288653          ...
# 1     -0.429577   -0.570750    1.171992   -0.288653          ...
# 2      0.830215    0.325915    0.092907   -0.288653          ...
# 3     -0.720298   -0.570750   -0.499274   -0.288653          ...
# 4      0.733308    1.366489    0.463568   -0.288653          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %%
x= house.drop('SalePrice', axis=1)
y= house.SalePrice

# %%
from sklearn.decomposition import PCA
pc =PCA(n_components= 120)
Pcomp = pc.fit_transform(x)
pc.explained_variance_ratio_
# Out:
# array([0.06300203, 0.02917488, 0.0234445 , 0.01960213, 0.01668117,
#        0.01596501, 0.01437836, 0.01292778, 0.01275215, 0.01209644,
#        0.01156809, 0.01108615, 0.01073786, 0.01050149, 0.01005786,
#        0.00978072, 0.00975056, 0.00938623, 0.0093499 , 0.00890139,
#        0.00872728, 0.00852031, 0.00847176, 0.00830204, 0.00812521,
#        0.00801972, 0.0079265 , 0.00776189, 0.00758399, 0.00754828,
#        0.00741185, 0.00731305, 0.00724764, 0.00709367, 0.00702989,
#        0.00696166, 0.00691956, 0.00681011, 0.00665841, 0.0065011 ,
#        0.00639193, 0.0063544 , 0.00629088, 0.00612756, 0.00602027,
#        0.00598846, 0.00593098, 0.00588947, 0.00573235, 0.00571765,
#        0.0056798 , 0.00558113, 0.00551923, 0.00545245, 0.00537943,
#        0.00534562, 0.00526383, 0.00521631, 0.00517213, 0.00511253,
#        0.00507456, 0.00496773, 0.00492511, 0.00484012, 0.004831  ,
#        0.00475499, 0.00473229, 0.00469677, 0.00467305, 0.00462868,
# ...

# %%
variance = 0
for i in range(120):
    variance = variance + pc.explained_variance_ratio_[i]
variance
# Out:
# 0.8175243079239176

# %%
x_train, x_test, y_train, y_test = train_test_split(Pcomp,y,test_size=0.3,random_state=122)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
ypred= linreg.predict(x_test)

# %%
np.sqrt(np.mean((ypred-y_test)**2))
# Out:
# 0.4335742116733101

# %%
from statsmodels.api import add_constant
import statsmodels.formula.api as sm

x2= add_constant(Pcomp)
lm= sm.OLS(y,x2)
ln=lm.fit()
print(ln.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.872
# Method:                 Least Squares   F-statistic:                     83.95
# Date:                Thu, 24 Jan 2019   Prob (F-statistic):               0.00
# Time:                        14:50:46   Log-Likelihood:                -507.35
# No. Observations:                1460   AIC:                             1257.
# Df Residuals:                    1339   BIC:                             1896.
# Df Model:                         120
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.025e-16      0.009    4.3e-14      1.000      -0.018       0.018
# ...

# %%
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH           80    11622   Pave  Grvl      Reg
# 1  1462          20       RL           81    14267   Pave  Grvl      IR1
# 2  1463          60       RL           74    13830   Pave  Grvl      IR1
# 3  1464          60       RL           78     9978   Pave  Grvl      IR1
# 4  1465         120       RL           43     5005   Pave  Grvl      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0     Ex  MnPrv
# 1         Lvl    AllPub      ...                 0        0     Ex  MnPrv
# 2         Lvl    AllPub      ...                 0        0     Ex  MnPrv
# 3         Lvl    AllPub      ...                 0        0     Ex  MnPrv
# 4         HLS    AllPub      ...               144        0     Ex  MnPrv
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test=pd.get_dummies(test)
test.drop('Id', axis=1, inplace=True)
col = test.columns
test=sc.fit_transform(test)
test = pd.DataFrame(test, columns=col)


test.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   -0.874711     0.567330  0.363929    -0.751101     0.400766  -0.340945
# 1   -0.874711     0.615963  0.897861    -0.054877     0.400766  -0.439695
# 2    0.061351     0.275532  0.809646    -0.751101    -0.497418   0.844059
# 3    0.061351     0.470064  0.032064    -0.054877     0.400766   0.876976
# 4    1.465443    -1.232092 -0.971808     1.337571    -0.497418   0.679475
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2          ...            \
# 0     -1.072885   -0.563316    0.063428    0.517537          ...
# 1     -1.214908    0.047057    1.063511   -0.297689          ...
# 2      0.678742   -0.563316    0.773377   -0.297689          ...
# 3      0.678742   -0.450284    0.357958   -0.297689          ...
# 4      0.394694   -0.563316   -0.387160   -0.297689          ...
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %%
from sklearn.decomposition import PCA
pc =PCA(n_components= 120)
Pcomp = pc.fit_transform(test)

# %%
Pcomp.shape
# Out:
# (1459, 120)

# %%
ypred= linreg.predict(Pcomp)

# %%
ypred
# Out:
# array([105924.81811404, 192463.77823539, 213664.62688891, ...,
#        180183.58640526, 129512.04820395, 228281.65306632])

# %%
ypred
# Out:
# array([105924.81811404, 192463.77823539, 213664.62688891, ...,
#        180183.58640526, 129512.04820395, 228281.65306632])

# %%
final = np.array(np.ravel(ypred))

# %%
final.shape
# Out:
# (1459,)

# %%
test = pd.read_csv('test.csv')

# %%
id= np.array(test.Id)

# %%
newdf = pd.DataFrame({'Id': id, 'SalePrice': final})

# %%
newdf.head()
# Out:
#      Id      SalePrice
# 0  1461  105924.818114
# 1  1462  192463.778235
# 2  1463  213664.626889
# 3  1464  239203.097406
# 4  1465  159926.334514

# %%
newdf.to_csv('Prediction.csv', index=False)

# %%
house.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL           65     8450   Pave  Grvl      Reg
# 1          20       RL           80     9600   Pave  Grvl      Reg
# 2          60       RL           68    11250   Pave  Grvl      IR1
# 3          70       RL           60     9550   Pave  Grvl      IR1
# 4          60       RL           84    14260   Pave  Grvl      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub    Inside    ...            0     Gd  MnPrv
# 1         Lvl    AllPub       FR2    ...            0     Gd  MnPrv
# 2         Lvl    AllPub    Inside    ...            0     Gd  MnPrv
# 3         Lvl    AllPub    Corner    ...            0     Gd  MnPrv
# 4         Lvl    AllPub       FR2    ...            0     Gd  MnPrv
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0        Shed       0      2    2008        WD         Normal     208500
# ...

# %%
y = house.SalePrice

# %%
sc.fit_transform(pd.DataFrame(y))
# Out:
# array([[ 0.34727322],
#        [ 0.00728832],
#        [ 0.53615372],
#        ...,
#        [ 1.07761115],
#        [-0.48852299],
#        [-0.42084081]])

# %%
ypred = sc.inverse_transform(ypred)
