# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook  
# this will allow the 3d plot to render
from mpl_toolkits.mplot3d import Axes3D
df=pd.read_csv("Iris.csv")
df.drop('Id',axis=1,inplace=True)
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
x=df.iloc[:,0]
y=df.iloc[:,1]
ax.scatter(x,y,c=df.iloc[:,0],marker='o')
ax.set_xlabel("sepallenghtcm")
ax.set_ylabel("sepalwidthcm")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
features=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',]
y=df.loc[:, 'Species']
x=df.loc[:,features]


x=sc.fit_transform(x)


from sklearn.decomposition import PCA
pc=PCA(n_components=2)
pcomp=pc.fit_transform(x)




pc.components_
# Out:
# array([[ 0.52237162, -0.26335492,  0.58125401,  0.56561105],
#        [ 0.37231836,  0.92555649,  0.02109478,  0.06541577]])

# %%
pc.get_covariance
# Out:
# <bound method _BasePCA.get_covariance of PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)>

# %%
pc.explained_variance_ratio_
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
# let plot this first we will create a DataFrame of this>>>>>>>>>>
pdf=pd.DataFrame(pcomp,columns=['pc1','pc2'])
fdf=pd.concat([pdf,df[['Species']]],axis=1)

# %%
fdf.head()
# Out:
#         pc1       pc2      Species
# 0 -2.264542  0.505704  Iris-setosa
# 1 -2.086426 -0.655405  Iris-setosa
# 2 -2.367950 -0.318477  Iris-setosa
# 3 -2.304197 -0.575368  Iris-setosa
# 4 -2.388777  0.674767  Iris-setosa

# %%
df.Species.value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
list(df.Species.unique())
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
plt.figure()
target=list(df.Species.unique())
color=['r','g','b']

plt.scatter(x=fdf.iloc[:,0],y=fdf.iloc[:,1],s=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import seaborn as sns
sns.pairplot(df,hue="Species")
# Out:
# <img src="data:image/png;base64,..." width="1028.8">
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(fdf.iloc[:,0],fdf.iloc[:,1])
# Out:
# <img src="data:image/png;base64,..." width="432">
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,[0,1,2,3]].values
y=df.iloc[:,4].values
xtr,xt,ytr,yt=train_test_split(x,y,test_size=.3,random_state=123)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rs=RandomForestClassifier(random_state=123)
rs.fit(xtr,ytr)
pr=rs.predict(xt)
rc=accuracy_score(yt,pr)
from sklearn import metrics
cr=metrics.classification_report(yt,p)
print(cr)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.88      0.94        17
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.94      0.96      0.95        45
#    weighted avg       0.96      0.96      0.96        45
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()
model=l.fit(xtr,ytr)
p=model.predict(xt)
lc=accuracy_score(yt,p)
from sklearn import metrics
cl=metrics.classification_report(yt,p)
# Out:
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtr=sc.fit_transform(xtr)
xt=sc.transform(xt)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rs=RandomForestClassifier(random_state=123)
rs.fit(xtr,ytr)
pr=rs.predict(xt)
rcs=accuracy_score(yt,pr)
from sklearn import metrics
crs=metrics.classification_report(yt,p)
# Out:
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()
model=l.fit(xtr,ytr)
p=model.predict(xt)
lcs=accuracy_score(yt,p)
from sklearn import metrics
cls=metrics.classification_report(yt,p)
# Out:
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
from sklearn.decomposition import PCA
pc=PCA(n_components=None)
xtr=pc.fit_transform(xtr)
xt=pc.transform(xt)
exp=pc.explained_variance_ratio_
exp
# Out:
# array([0.73135923, 0.22091301, 0.04277691, 0.00495085])

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rs=RandomForestClassifier(random_state=123)
rs.fit(xtr,ytr)
pr=rs.predict(xt)
rcp=accuracy_score(yt,pr)
from sklearn import metrics
crp=metrics.classification_report(yt,p)
# Out:
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression
l=LogisticRegression()
model=l.fit(xtr,ytr)
p=model.predict(xt)
lcp=accuracy_score(yt,p)
from sklearn import metrics
clp=metrics.classification_report(yt,p)
# Out:
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pokas\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
# split,split-scaling,split-scaling-pca
print(lc,lcs,lcp)
# Out:
# 0.9777777777777777 0.9555555555555556 0.9555555555555556

# %%
print(rc,rcs,rcp)
# Out:
# 0.9555555555555556 0.9555555555555556 0.9555555555555556

# %%
print(cr)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.88      0.94        17
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.94      0.96      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(crs)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.94      0.97        17
#
#       micro avg       0.98      0.98      0.98        45
#       macro avg       0.97      0.98      0.97        45
#    weighted avg       0.98      0.98      0.98        45

# %%
print(crp)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.88      0.94        17
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.94      0.96      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(cl)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.94      0.97        17
#
#       micro avg       0.98      0.98      0.98        45
#       macro avg       0.97      0.98      0.97        45
#    weighted avg       0.98      0.98      0.98        45

# %%
print(cls)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.88      0.94        17
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.94      0.96      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %%
print(clp)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.83      1.00      0.91        10
#  Iris-virginica       1.00      0.88      0.94        17
#
#       micro avg       0.96      0.96      0.96        45
#       macro avg       0.94      0.96      0.95        45
#    weighted avg       0.96      0.96      0.96        45

# %%
fdf.head()
# Out:
#         pc1       pc2      Species
# 0 -2.264542  0.505704  Iris-setosa
# 1 -2.086426 -0.655405  Iris-setosa
# 2 -2.367950 -0.318477  Iris-setosa
# 3 -2.304197 -0.575368  Iris-setosa
# 4 -2.388777  0.674767  Iris-setosa

# %%
plt.figure()
plt.scatter(x="pc1",y="pc2",hue="Species",data=fdf)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-69685403426e> in <module>
#       1 plt.figure()
# ----> 2 plt.scatter(x="pc1",y="pc2",hue="Species",data=fdf)
#       3 plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
